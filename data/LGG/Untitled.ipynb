# %%
import pandas as pd

# %%
df = pd.read_csv('./rna.csv.gz', compression='gzip')
df
# Out:
#             gene  TCGA.DH.5140  TCGA.WH.A86K  TCGA.HT.7680  TCGA.DU.8167  \
# 0              1        4.6185        8.4603        5.4552        6.6581
# 1              2       13.1572       13.6312       13.2631       14.1168
# 2              9        4.4636        3.7677        6.4637        4.2737
# 3             10        1.9695        5.1641        3.5389        3.7103
# 4             12       11.5545       10.8544       15.2290       11.4204
# ...          ...           ...           ...           ...           ...
# 17041  101340250        0.0000        0.0000        0.0000        0.0000
# 17042  102723547        1.4405        0.0000        0.0000        0.0000
# 17043  102724473        0.0000        0.6790        1.0964        0.0000
# 17044  105375355        1.3897        1.1387        0.4640        2.2485
# 17045  107133522        0.0000        0.0000        0.0000        0.0000
#
#        TCGA.HT.A5R7  TCGA.DH.A66D  TCGA.S9.A89Z  TCGA.HT.8108  TCGA.TQ.A7RJ  \
# ...
